# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/07math_moudule.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Mathematics

# %%
# find min
x = min(33,4,5,67,88)
x
# Out:
# 4

# %%
# find the maximum number
z = max(33,4,5,775,54,333)
z
# Out:
# 775

# %%
# sum the value
y = sum([33,42,111])
y
# Out:
# 186

# %%
#
import math
x = math.sqrt(64)
x
# Out:
# 8.0

# %%
math.floor (3.44)
# Out:
# 3

# %%
math.ceil (3.33)
# Out:
# 4

# %%
math.trunc (33.4)
# Out:
# 33

# %%
#factorial
math.factorial (5)
# Out:
# 120

# %%
# user input
firstname = 'Hafiz'
lastname = 'Adnan'
fullname = firstname + ' ' + lastname
fullname
# Out:
# 'Hafiz Adnan'

# %%
# user input
firstname = input('Enter your name')
lastname = input('Enter your name')
fullname = firstname + ' ' + lastname
fullname
# Out:
# Enter your nameAdnan
# Enter your namesami
# 'Adnan sami '

# %%
a = int (input("Provide first value"))
b = int (input('Provide second value'))
sum = a + b
sum
# Out:
# Provide first value33
# Provide second value23
# 56

# %%
# from this method we give just value and it give us output
res = eval(input('Enter expression'))
res
# Out:
# Enter expression2+4*5-6
# 16
