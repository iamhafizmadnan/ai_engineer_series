# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/02_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Variables**

# %%
# In this case id, name , roll_no is variable those store value.
id1 = 333
name = 'Hafiz Muhammad Adnan'
roll_no = 32

# %%
print (id1)
# Out:
# 333

# %%
print (name)
# Out:
# Hafiz Muhammad Adnan

# %%
print (roll_no)
# Out:
# 32

# %% [markdown]
# # you can easily call value using variable name.

# %%
#take input from user.
del input
input ('Please enter your name')
# Out:
# Please enter your namehafiz m adnan
# 'hafiz m adnan'

# %%
name = input()
# Out:
# Adnan

# %%
print(name)
name
# Out:
# Adnan
# 'Adnan '

# %%
#concatenation only with string
name = "Hafiz"  + " Muhammad" + " Adnan"
name
# Out:
# 'Hafiz Muhammad Adnan'

# %%
# can not concatenate with other string or numbers
name = "Hafiz" + 333
name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2668154242.py in <cell line: 0>()
#       1 # can not concatenate with other string or numbers
# ----> 2 name = "Hafiz" + 333
#       3 name
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Calling index
student = "ALI RAZA "
print (student[0])
# Out:
# A

# %%
student[4]
# Out:
# 'R'

# %%
student[-3]
# Out:
# 'Z'

# %%
fruits = 'apple','orange', 'bannana'

# %%
print (fruits)
# Out:
# ('apple', 'orange', 'bannana')
