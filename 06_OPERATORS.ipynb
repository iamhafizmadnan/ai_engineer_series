# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/06_OPERATORS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIRTHMETIC OPERATOR

# %% [markdown]
# ## 1.   Addition
# ## 2.   Multiplication
# ## 3.   Subtraction
# ## 4.   Division (Float)
# ## 5.   Floor Division
# ## 6.   Modulus (Reminder)
# ## 7.   Exponentation (Power)

# %% [markdown]
# # COMPARISON OPERATOR

# %% [markdown]
# # 1. Equal to == True
# # 2. Not Equal to != True
# # 3. Greater Than >
# # 4. Less Than <
# # 5. Greater Than Equal to >=
# # 6. Less than Eqal to <=

# %%
# Comparison operator
a = 2 == 2
a
# Out:
# True

# %%
b = 33 != 23
b
# Out:
# True

# %%
a = 44 > 99
a
# Out:
# False

# %%
a = 23 < 99
a
# Out:
# True

# %% [markdown]
# # Logical Operator

# %% [markdown]
# # AND
# # 1. True if both are true
# # OR
# # 2. True if atleast one is True
# # NOT
# # 3. Reverse the result

# %%
# logical operator and, or , not
x = (3>5) and (5>3)
x
# Out:
# False

# %%
x = 33 > 23 or 23 < 33
x
# Out:
# True

# %%
x = not(33 > 23 or 23 < 33)
x
# Out:
# False

# %% [markdown]
# # Assignment Operator

# %% [markdown]
# ## 1.  Assign               =
# ## 2.  Add and assgin      +=
# ## 3.  Subtract and assign -=
# ## 4.  Multiply and assign *=
# ## 5.  Divide and assign   /=
# ## 6.  Floor divide and assign //=
# ## 7.  Modulus and assign  %=

# %%
# Assignment operator
a = 5
a += 3
a
# Out:
# 8

# %%
a -= 5
a
# Out:
# -2

# %%
a *= 8
a
# Out:
# -16

# %%
x = 55
x /= 2
x
# Out:
# 27.5

# %%
x  //= 20
x
# Out:
# 0.0

# %% [markdown]
# # Membership Operator

# %% [markdown]
# ## Retrun true if value is found   (in)
# ## Retrun ture if value is not found

# %%
x = 'a' in 'alpha '
x
# Out:
# True

# %%
x = 'b ' in 'alpha'
x
# Out:
# False

# %%
x = 'b ' not in 'alpha'
x
# Out:
# True

# %% [markdown]
# # Identity Operator

# %% [markdown]
# ## 1. True if both refer to the same object  (is)
# ## 2. True if both are different             (is not )

# %%
# identity operator
x = [2,34,5]
y = [3,4,5]
x = y
z = x is y
z
# Out:
# False

# %%
x = [2,34,5]
y = [3,4,5]
z = x is not y
z
# Out:
# True
