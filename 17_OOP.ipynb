# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/17_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Oriented Programming

# %%
class employee:
  def __init__(self):
    # attribute
    self.name = 'Adnan'
    self.rollno = 12

student = employee()
print(student.name)
print(student.rollno)
# Out:
# Adnan
# 12
