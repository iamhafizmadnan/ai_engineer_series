# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/08_if_elif_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
passingmarks = 70
score = int (input('Enter your marks:'))

if score == 100:
  print("You are great!")
elif score >= passingmarks:
  print("you passed the exam")
elif score < passingmarks:
  print("you failed the exam")
print("i have checked your marks")
# Out:
# Enter your marks:100
# You are great!
# i have checked your marks

# %%
passingmarks = 70
score = int (input('Enter your marks:'))

if score == 100:
  print("You are great!")
elif score >= passingmarks:
  print("you passed the exam")
elif score < passingmarks:
  print("you failed the exam")
print("i have checked your marks")
# Out:
# Enter your marks:80
# you passed the exam
# i have checked your marks

# %%
passingmarks = 70
score = int (input('Enter your marks:'))

if score == 100:
  print("You are great!")
elif score >= passingmarks:
  print("you passed the exam")
elif score < passingmarks:
  print("you failed the exam")
print("i have checked your marks")
# Out:
# Enter your marks:50
# you failed the exam
# i have checked your marks

# %%
employeed = False
if employeed == True:
  print("you are an employee")
else:
  print("you are not an employee")
# Out:
# you are not an employee

# %% [markdown]
# # calculator

# %%
num1 = float(input('Enter first number:'))
num2 = float(input('Enter second number:'))
op = input('Enter operator: (+,-,*,/)' )
if op == '+':
  print(num1 + num2)
elif op == '-':
  print(num1 - num2)
elif op == '*':
  print(num1 * num2)
elif op == '/':
  print(num1 / num2)
else:
  print("invalid operator")
# Out:
# Enter first number:22
# Enter second number:2
# Enter operator: (+,-,*,/)+
# 24.0
