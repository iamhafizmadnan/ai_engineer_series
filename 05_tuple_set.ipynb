# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/05_tuple_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tuple**
# 1. Tuple is immutable , not changeable
# 2. Tuple is ordered and allow duplicate values.

# %%
tup = ('ali', 'raza',' usman')
tup
# Out:
# ('ali', 'raza', ' usman')

# %%
# access the tuple item
tup[2]
# Out:
# ' usman'

# %%
tup[-3]
# Out:
# 'ali'

# %%
name = ('ali', 'ali','raza')
name
# Out:
# ('ali', 'ali', 'raza')

# %% [markdown]
# **SETS**
# 1. Sets are unordered , unchangeable and unindexed

# %%
#
s = {3,44,5,6}
s
# Out:
# {3, 5, 6, 44}

# %%
#duplicate is not allowed
s = {dd,dd, saas,ddg}
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2064829882.py in <cell line: 0>()
#       1 #duplicate is not allowed
# ----> 2 s = {dd,dd, saas,ddg}
#       3 s
#
# NameError: name 'dd' is not defined

# %%
# join the set in this case we can use modulus operator.
fruit = {'apple', 'mango','orange'}
price = {50, 90, 100}
total = fruit | price
total
# Out:
# {100, 50, 90, 'apple', 'mango', 'orange'}
