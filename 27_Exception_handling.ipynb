# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/27_Exception_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exception Handling
#
#
# *   When an error occurs, or exception as we call it, Python will normally stop and generate an error message.

# %%
try:
  print(z)
except:
  print("I don't know about it")
# Out:
# I don't know about it

# %%
try:
  print(x)
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")
# Out:
# Variable x is not defined

# %% [markdown]
# ## Else

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %% [markdown]
# ## Finally

# %%
try:
  print(y)
except:
  print("Something went wrong")
finally:
  print("The 'try except' is finished")
# Out:
# Something went wrong
# The 'try except' is finished

# %%
try:
  x = int(input('Plz enter the number for x: '))
  y = int(input('Plz enter the number for y: '))
  result = x/y
  print(result)
except ValueError:
  print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
  print("Cannot divide by zero.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# Plz enter the number for x: 8
# Plz enter the number for y: y
# Invalid input. Please enter a valid number.
