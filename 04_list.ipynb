# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/04_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **List**

# %% [markdown]
# 1.   List are ordered
# 2.   List are changeable , and allow duplicate values.

# %%
# List
fruits = ['Apple', 'orange', 'bannana', 'mango']
fruits
# Out:
# ['Apple', 'orange', 'bannana', 'mango']

# %%
# for getting index value
fruits [3]
# Out:
# 'mango'

# %%
fruits [-3]
# Out:
# 'orange'

# %%
num = [3,34,5,6,7]
num
# Out:
# [3, 34, 5, 6, 7]

# %%
# range of indedx
num[1:3]
# Out:
# [34, 5]

# %%
num [:5]
# Out:
# [3, 34, 5, 6, 7]

# %%
num[2:]
# Out:
# [5, 6, 7, 44]

# %%
#change list item
name = ['ali', 'zain', 'usman', 'raza']
name[2] = 'khizar'
name
# Out:
# ['ali', 'zain', 'khizar', 'raza']

# %%
# change value by range
name [ 0:2] = ['adnan', 'smai']
name
# Out:
# ['adnan', 'smai', 'khizar', 'raza']

# %%
# insert the new value
name.insert (3, ' iqrash')
name
# Out:
# ['adnan', 'smai', 'khizar', ' iqrash', 'raza']

# %%
# add the item
name.append('usman')
name
# Out:
# ['adnan', 'smai', 'khizar', ' iqrash', 'raza', 'usman', 'usman', 'usman']

# %%
# remove the item
name.remove('usman')
name
# Out:
# ['adnan', 'smai', 'khizar', ' iqrash', 'raza', 'usman']

# %%
name.pop(3)
name
# Out:
# ['adnan', 'smai', 'khizar', 'raza', 'usman']

# %%
del name[2]
name
# Out:
# ['adnan', 'smai', 'raza', 'usman']

# %%
# clear the list but it still remain the space
name.clear()
name
# Out:
# []

# %%
# copy of the fun
name = ['ali', 'zain', 'usman', 'raza']
name1 = name.copy()
name1
# Out:
# ['ali', 'zain', 'usman', 'raza']

# %%
print(len(num))
# Out:
# 5

# %%
print (type(num))
# Out:
# <class 'list'>

# %%
num.append(44)

# %%
num
# Out:
# [3, 34, 5, 6, 7, 44]

# %%
# sorting the list
num.sort()
num
# Out:
# [3, 5, 6, 7, 34, 44]

# %%
num.sort (reverse = True)
num
# Out:
# [44, 34, 7, 6, 5, 3]

# %%
# copy the list
num1  = num.copy()
num
# Out:
# [44, 34, 7, 6, 5, 3]

# %%
num2 = list(num1)
num2
# Out:
# [44, 34, 7, 6, 5, 3]

# %%
# also using slice operator
num3 = num2[:]
num3
# Out:
# [44, 34, 7, 6, 5, 3]

# %%
# join list
num4 = num + num3
num4
# Out:
# [44, 34, 7, 6, 5, 3, 44, 34, 7, 6, 5, 3]

# %%
name = ['ali','raze','xobi']
age = [22,34,54]
join = name + age
join
# Out:
# ['ali', 'raze', 'xobi', 22, 34, 54]
