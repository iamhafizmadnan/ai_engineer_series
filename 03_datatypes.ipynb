# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/03_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Types**

# %% [markdown]
# 7 Types of data
# 1. Numeric
#    ->INT
#    ->FLOAT
#    ->COMPLEX Number
# 2. String
# 3. Sequence
#    ->List
#    ->Tuple
#    ->Range
# 4. Mapping
#    ->Dictionary
# 5. Set
# 6. Boolean
#    ->True
#    ->False
# 7. None

# %%
# Numeric
# int type
var = 7
type(var)
# Out:
# int

# %%
# float type
var = 33.33
type(var)
# Out:
# float

# %%
# complex type
com = 3 + 9j
type(com)
# Out:
# complex

# %%
x = 4
# convert the int into float
y = float(x)

type(y)
# Out:
# float

# %%
c = complex (3+5)
c
# Out:
# (8+0j)

# %%
# 2. String
s = "Python"
type(s)
# Out:
# str

# %%
s = 'string ha ya nhhi'
type(s)
# Out:
# str

# %%
# 3. Sequence , list , tuple , range

list = [ 33,34,45,55,677]
type(list)
# Out:
# list

# %%
# Tuple
tup = ( 33,34,45,55,677)
type(tup)
# Out:
# tuple

# %%
from os import RTLD_DEEPBIND
# range
r = range (22)
r
type(r)
# Out:
# range

# %%
# 4. Mapping -> Dictionary
d = {
    "name" : "Ali",
    "age" : 22
}
type(d)
# Out:
# dict

# %%
d['name']
# Out:
# 'Ali'

# %%
d.values()
# Out:
# dict_values(['Ali', 22])

# %%
d.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
# 5. set
s = { 33,34,45,55,677}
type(s)
# Out:
# set

# %%
# Boolean Type
a = 4
b = 2
c = a > b
c
# Out:
# True

# %%
a =  33
b = 88
c = a > b
c
# Out:
# False
