# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/12_arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Arrays

# %%
import array
from array import *

# %%
arr = array ('i', [1,23,4,5])
arr
type(arr)
# Out:
# array.array

# %%
# insert the value
arr.insert(2, 55)
arr
# Out:
# array('i', [1, 23, 55, 4, 5])

# %%
# access the value
arr[2]
# Out:
# 55

# %%
# modify the value
arr[2] = 33
arr
# Out:
# array('i', [1, 23, 33, 4, 5])

# %%
# mesure the length
a = len(arr)
a
# Out:
# 5

# %%
# adding the element
arr.append(44)
arr
# Out:
# array('i', [1, 23, 33, 4, 5, 44])

# %%
# remove the value
arr.remove(1)
arr
# Out:
# array('i', [23, 33, 5, 44])

# %%
# pop the value
arr.pop(2)
arr
# Out:
# array('i', [23, 33, 44])
