# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Basic of python**

# %% [markdown]
# ##Comment

# %%
name = "Hafiz Adnan"
# print my name using given variable (This is comment those not show in code.)
print(name)
# Out:
# Hafiz Adnan

# %%
section = "CSB"
print(section)
Print(section)  # Python is case sensitive language.
# Out:
# CSB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2324285172.py in <cell line: 0>()
#       1 section = "CSB"
#       2 print(section)
# ----> 3 Print(section)
#
# NameError: name 'Print' is not defined

# %%
# You can write value in single or double inverted commas.
name_1 = "Adnan"
name_2= 'Ali Raza'
print(name_1)
print(name_2)
# Out:
# Adnan
# Ali Raza

# %%
# First line not run because when ending and starting from double commas always in center single comma.
# print("He said, "yes you can do it." ")
print("He said, 'yes you can do it' ")
# Out:
# He said, 'yes you can do it'

# %%
# First line not run because when starting and ending start from single
# inverted commas in center you can not use single inverted commas.
#print ( 'He said , 'yes i say to you ' ')
print ( 'He said, "yes you you can do it" ')
# Out:
# He said, "yes you you can do it"

# %%
# If you want to print any folder address then you must use "r" function.
print (r'c:\user\folder')
# Out:
# c:\user\folder

# %% [markdown]
# **Airthmetic Operation**

# %%
7
# Out:
# 7

# %%
print('Addiction:', 5 + 5)
print('Subtraction:', 45 - 34)
print("Multiplication: ", 3 * 4)
print ('Division:' , 10 / 2)
print("Floor Division:",11 // 2)
print ("Modulus Divison:" , 11 % 2)
print ("Exponatiotion:" , 3**3)
# Out:
# Addiction: 10
# Subtraction: 11
# Multiplication:  12
# Division: 5.0
# Floor Division: 5
# Modulus Divison: 1
# Exponatiotion: 27
