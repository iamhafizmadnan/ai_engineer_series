# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhafizmadnan/ai_engineer_series/blob/main/10_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # String Function

# %%
name = ' hafiz adnan '
name.upper()
# Out:
# ' HAFIZ ADNAN '

# %%
name.lower()
# Out:
# 'hafiz adnan'

# %%
name.title()
# Out:
# 'Hafiz Adnan'

# %%
name.strip()
# Out:
# 'hafiz adnan'

# %%
name.lstrip()
# Out:
# 'hafiz adnan'

# %%
name.rstrip()
# Out:
# ' hafiz adnan'

# %%
name.find('d')
# Out:
# 8

# %%
name.replace ('d','f')
# Out:
# ' hafiz afnan '

# %%
len(name)
# Out:
# 13

# %%
# string indexing
name = "Hafiz Adnan"
print(name[7])
print(name[-8])
print(name[1:5])
# Out:
# d
# i
# afiz

# %%
#myemail = hafizmadnan567@gmail.com
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-613549943.py in <cell line: 0>()
# ----> 1 myemail = hafizmadnan567@gmail.com
#       2
#       3
#
# NameError: name 'hafizmadnan567' is not defined
